# %%
# malik
import pandas as pd
import folium

def cor():           # importation des éléments 
    data = pd.read_csv("data.csv", encoding='CP1252', sep=';')
    if not {"Expérimentateur", "Latitude", "Longitude","Bande de fréquences", "Fréquences attribuées (limite basse)", "Fréquences attribuées (limite haute)",  "Code INSEE", "Début", "Fin", }.issubset(data.columns):
        raise ValueError("Colonnes manquantes")
    result = []        # création liste 
    for _, row in data.iterrows():                    # conversion des coordonées      
        lat = float(str(row['Latitude']).replace(',', '.'))
        lon = float(str(row['Longitude']).replace(',', '.'))
        bdf = str(row['Bande de fréquences'])     
        result.append((row['Expérimentateur'], bdf, row["Fréquences attribuées (limite basse)"], row["Fréquences attribuées (limite haute)"], row["Code INSEE"], row["Début"], row["Fin"], lat, lon)) # ajout des élements a la liste
    return result

coords = cor() 

carte = folium.Map(location=[coords[0][7], coords[0][8]], zoom_start=6)  #création de la carte avec le rajout des coordonées de Latitude et de Latitude

for experimentateur, bande, freq_b, freq_h, insee, debut, fin, lat, lon in coords:
    folium.Marker(           # crétion des markers et rajout des elements des élèments
        location=[lat, lon],        
        popup=f"""<b>{experimentateur}</b>     
fréquences: {bande}<br>
limite basse: {freq_b}<br>
limite haute: {freq_h}<br>
INSEE: {insee}<br>
Début: {debut}<br>
Fin: {fin}<br> """, 
        tooltip=experimentateur
    ).add_to(carte)
    
carte
# Out:
# Index(['Expérimentateur', 'Bande de fréquences',
#        'Fréquences attribuées (limite basse)',
#        'Fréquences attribuées (limite haute)',
#        'Numéro de la décision d'autorisation de l'Arcep',
#        'Lien de la décision d'autorisation de l'Arcep', 'Latitude',
#        'Longitude', 'Code INSEE', 'Commune', 'Département', 'Région', 'Début',
#        'Fin', 'Description', 'Techno - Massive MIMO',
#        'Techno - Beamforming/beamtracking',
#        'Techno - Duplexage temporel (mode TDD)',
#        'Techno - Mode de fonctionnement NSA (Non Stand Alone)',
#        'Techno - Mode de fonctionnement SA (Stand Alone)',
#        'Techno - Synchronisation de réseaux', 'Techno - Network slicing',
#        'Techno - Small cells', 'Techno - Accès dynamique au spectre',
#        'Techno - 5G, 6G…', 'Usage - Mobilité connectée',
#        'Usage - Internet des objets', 'Usage - Ville intelligente',
#        'Usage - Réalité virtuelle', 'Usage - Télémédecine',
#        'Usage - Industrie du futur', 'Usage - Autre'],
#       dtype='object')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8faeb2a0c5addab715328cbf50cb01f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8faeb2a0c5addab715328cbf50cb01f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8faeb2a0c5addab715328cbf50cb01f = L.map(
#                 &quot;map_f8faeb2a0c5addab715328cbf50cb01f&quot;,
#                 {
#                     center: [47.2919444444444, -1.48444444444444],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2117e204a9658707d997b0f1fbc2895 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2117e204a9658707d997b0f1fbc2895.addTo(map_f8faeb2a0c5addab715328cbf50cb01f);
#
#
#             var marker_cc00902c85dbac8b8c25ee1a8515579e = L.marker(
#                 [47.2919444444444, -1.48444444444444],
#                 {
# }
#             ).addTo(map_f8faeb2a0c5addab715328cbf50cb01f);
#
#
#         var popup_d9abbe03e7e4b51ad9bebfe1712b7603 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd09f5c848a4c97dbcd00c17f1f0b0a9 = $(`&lt;div id=&quot;html_fd09f5c848a4c97dbcd00c17f1f0b0a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;SNCF Réseau&lt;/b&gt;      fréquences: 2,6 GHz TDD&lt;br&gt; limite basse: 2575&lt;br&gt; limite haute: 2595&lt;br&gt; INSEE: 44026&lt;br&gt; Début: 2022-05-12&lt;br&gt; Fin: 2025-12-31&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_d9abbe03e7e4b51ad9bebfe1712b7603.setContent(html_fd09f5c848a4c97dbcd00c17f1f0b0a9);
#
#
#
#         marker_cc00902c85dbac8b8c25ee1a8515579e.bindPopup(popup_d9abbe03e7e4b51ad9bebfe1712b7603)
#         ;
#
#
#
#
#             marker_cc00902c85dbac8b8c25ee1a8515579e.bindTooltip(
#                 `&lt;div&gt;
#                      SNCF Réseau
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_42465a6d9e0eac723d04f1c65a255083 = L.marker(
#                 [47.312245, -2.169842],
#                 {
# }
#             ).addTo(map_f8faeb2a0c5addab715328cbf50cb01f);
#
#
#         var popup_fa75b1ddbabc833cc3ee050bb4a4fabb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a3effffd7695897e3f95daf21a3880e = $(`&lt;div id=&quot;html_8a3effffd7695897e3f95daf21a3880e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Airbus Operations SAS&lt;/b&gt;      fréquences: 3,8 GHz&lt;br&gt; limite basse: 3900&lt;br&gt; limite haute: 4000&lt;br&gt; INSEE: 44184&lt;br&gt; Début: 2023-01-01&lt;br&gt; Fin: 2025-12-31&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_fa75b1ddbabc833cc3ee050bb4a4fabb.setContent(html_8a3effffd7695897e3f95daf21a3880e);
#
#
#
#         marker_42465a6d9e0eac723d04f1c65a255083.bindPopup(popup_fa75b1ddbabc833cc3ee050bb4a4fabb)
#         ;
#
#
#
#
#             marker_42465a6d9e0eac723d04f1c65a255083.bindTooltip(
#                 `&lt;div&gt;
#                      Airbus Operations SAS
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a2189d0628a15e0ea905e1c3ba39d9c3 = L.marker(
#                 [48.785, 2.20827],
#                 {
# }
#             ).addTo(map_f8faeb2a0c5addab715328cbf50cb01f);
#
#
#         var popup_12952684b3e4a15905e105df9a390768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9f279e9f6603a180c24ec3c0150162d = $(`&lt;div id=&quot;html_d9f279e9f6603a180c24ec3c0150162d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;GTS FRANCE SAS&lt;/b&gt;      fréquences: 3,8 GHz&lt;br&gt; limite basse: 3900&lt;br&gt; limite haute: 4000&lt;br&gt; INSEE: 78640&lt;br&gt; Début: 2023-03-30&lt;br&gt; Fin: 2026-03-29&lt;br&gt; &lt;/div&gt;`)[0];
#                 popup_12952684b3e4a15905e105df9a390768.setContent(html_d9f279e9f6603a180c24ec3c0150162d);
#
#
#
#         marker_a2189d0628a15e0ea905e1c3ba39d9c3.bindPopup(popup_12952684b3e4a15905e105df9a390768)
#         ;
#
#
#
#
#             marker_a2189d0628a15e0ea905e1c3ba39d9c3.bindTooltip(
#                 `&lt;div&gt;
#                      GTS FRANCE SAS
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b35b0eff1dfa9f313bee7832b06a577e = L.marker(
#                 [48.5759425, 7.7430558],
#                 {
# }
#             ).addTo(map_f8fae
